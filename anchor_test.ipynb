# %% [markdown]
# # Simple Title
#
# # Title With CAPS
#
# # Title with punctuation!
#
# # Title: with (parentheses)
#
# # Title_with_underscore
#
# # Title & Something
#
# # Duplicate Title
#
# # Duplicate Title
#
# # Unicode α β γ
#
# ## A very   spaced   title
